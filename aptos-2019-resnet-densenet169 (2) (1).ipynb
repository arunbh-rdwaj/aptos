# %% [markdown]
# ### Abstract
# We consider a starter code for beginner of this dataset. There is a unbalanced distribution of the classes. To overcome this drawback we want to add images by modifying the given images. We use the following geometric transformations:
# * vertical flip,
# * rotation,
# * perspective transformation (zoom).
#
# After that we select randomly images by the same number of images of every class.
#
# In consideration of the medical fact that there exists a course of disease we use multi-labels instead of single-labels. That means we set
#
# | diagnosis | single-label |multi-label |
# |---| ---| ---|
# | 0 | 0 | 0 |
# | 1 | 1 | 0, 1|
# | 2 | 2 | 0, 1, 2|
# | 3 | 3 | 0, 1, 2, 3|
# | 4 | 4 | 0, 1, 2, 3, 4|
#
# We trained the model by using a pretrained model.

# %%
import numpy as np
import pandas as pd
import random

import os
path_in = "../input/aptos2019-blindness-detection/"
print(os.listdir(path_in))
print(os.listdir('../input/models'))
# Out:
# ['sample_submission.csv', 'train_images', 'train.csv', 'test.csv', 'test_images']
# ['mask_rcnn_coco.h5', 'model_weights_resnet.h5', 'resnet50_weights_tf_dim_ordering_tf_kernels.h5', 'resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5', 'model_weights_vgg16.h5', 'efficientnetb3_notop.h5', 'mobilenet_1_0_224_tf_no_top.h5']

# %%
import cv2
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

# %%
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, Activation
from keras.optimizers import RMSprop,Adam
from keras.applications import VGG19
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Define some parameters

# %%
q_size = 150
img_channel = 3
num_classes = 5

# %% [markdown]
# ### Read the input csv files

# %%
train_data = pd.read_csv(path_in+'train.csv')
test_data = pd.read_csv(path_in+'test.csv')
sub_org = pd.read_csv(path_in+'sample_submission.csv')

# %% [markdown]
# ### Define some functions

# %%
def plot_bar(data):
    """Simple function to plot the distribution of the classes."""
    dict_data = dict(zip(range(0, num_classes), (((data.value_counts()).sort_index())).tolist()))
    names = list(dict_data.keys())
    values = list(dict_data.values())
    plt.bar(names, values)
    plt.grid()
    plt.show()

# %%
def read_images(filepath, data, file_list, size):
    """Read and edit the images of a given folder."""
    for file in file_list:
        img = cv2.imread(filepath+file+'.png')
        img = cv2.resize(img, (size, size))
        img = cv2.addWeighted(img, 4, cv2.GaussianBlur(img, (0, 0), 10), -4, 128)
        data[file_list.index(file), :, :, :] = img

# %%
def add_flip_image(data, file_list):
    """Simple function to flip images by a given list."""
    temp = np.empty((1, data.shape[1], data.shape[2], data.shape[3]), dtype=np.uint8)
    for index in file_list.index:
        img = data[index, :, :, :]
        vertical_img = cv2.flip(img, 1)
        temp[0, :, :, :] = vertical_img
        data = np.concatenate((data, temp), axis=0)
    return data

# %%
def add_rot_image(data, file_list):
    """Simple function to rotate images by a given list."""
    degrees = 15
    temp = np.empty((1, data.shape[1], data.shape[2], data.shape[3]), dtype=np.uint8)
    for index in file_list.index:
        img = data[index, :, :, :]
        rows,cols, channel = img.shape
        Matrix = cv2.getRotationMatrix2D((cols/2,rows/2), degrees, 1)
        rotate_img = cv2.warpAffine(img, Matrix, (cols, rows))
        temp[0, :, :, :] = rotate_img
        data = np.concatenate((data, temp), axis=0)
    return data

# %%
def add_zoom_image(data, file_list):
    """Simple function to zoom in images by a given list."""
    temp = np.empty((1, data.shape[1], data.shape[2], data.shape[3]), dtype=np.uint8)
    for index in file_list.index:
        img = data[index, :, :, :]
        size = img.shape[0]
        pts1 = np.float32([[10,10],[size-10, 10],[10, size-10],[size-10, size-10]])
        pts2 = np.float32([[0, 0],[size-20, 0],[0, size-20],[size-20, size-20]])
        Matrix = cv2.getPerspectiveTransform(pts1, pts2)
        # zoom image
        img_zoom = cv2.warpPerspective(img, Matrix, (size-20, size-20))
        dim = img.shape 
        # resize image
        rows,cols, channel = img.shape
        dim=(rows, cols)
        img_scale = cv2.resize(img_zoom, dim, interpolation = cv2.INTER_AREA)
        temp[0, :, :, :] = img_scale
        data = np.concatenate((data, temp), axis=0)
    return data

# %%
def get_multilabel(diagnosis):
    """A function to get multi-label from single-label."""
    return ','.join([str(i) for i in range(diagnosis + 1)])

# %% [markdown]
# ### Initialize the original train and test data

# %%
X_train_org = np.empty((len(train_data), q_size, q_size, img_channel), dtype=np.uint8)
X_test = np.empty((len(test_data), q_size, q_size, img_channel), dtype=np.uint8)

# %% [markdown]
# ### Read the image data

# %%
read_images(path_in+'train_images/', X_train_org, train_data['id_code'].tolist(), q_size)
read_images(path_in+'test_images/', X_test, sub_org['id_code'].tolist(), q_size)

# %%
plot_bar(train_data['diagnosis'])

# %% [markdown]
# ### Add flipped images
# Dublicate the images from class 1 to 4 by vertical flip every image.

# %%
list_flip = train_data[train_data['diagnosis'] != 0]

# %%
X_train_org = add_flip_image(X_train_org, list_flip)
train_data = train_data.append(list_flip, ignore_index=True, sort=False)

# %%
plot_bar(train_data['diagnosis'])

# %% [markdown]
# ### Add rotated images
# Dublicate the images from class 1, 3 and 4 by rotate every image.

# %%
list_rot = train_data[(train_data['diagnosis'] != 0)&
                      (train_data['diagnosis'] != 2)]

# %%
X_train_org = add_rot_image(X_train_org, list_rot)
train_data = train_data.append(list_rot, ignore_index=True, sort=False)

# %%
plot_bar(train_data['diagnosis'])

# %% [markdown]
# ### Add images by zooming
# Dublicate the images from class 3 and 4 by zooming every image.

# %%
list_zoom = train_data[(train_data['diagnosis'] == 3)|
                       (train_data['diagnosis'] == 4)]

# %%
X_train_org = add_zoom_image(X_train_org, list_zoom)
train_data = train_data.append(list_zoom, ignore_index=True, sort=False)

# %%
plot_bar(train_data['diagnosis'])

# %% [markdown]
# ### Select random images for train
# The aim is to get equally distributed images for every class.

# %%
num_val = (train_data['diagnosis'].value_counts()).min()
list_new = []
for i in range(num_classes):
    temp = random.choices(train_data[train_data['diagnosis']==i].index, k=num_val)
    list_new.extend(temp)
train_data = train_data.loc[list_new]
X_train_org = X_train_org[list_new]

# %%
plot_bar(train_data['diagnosis'])

# %% [markdown]
# ### Plot an image

# %%
image_number=4019
print(train_data.iloc[image_number])
plt.imshow(X_train_org[image_number], cmap='gray')
plt.show()
# Out:
# id_code      4a0bba3b7d83
# diagnosis               2
# Name: 4216, dtype: object

# %% [markdown]
# ### Prepare the labels
# Using multi-label instead of single-label.

# %%
train_data['multilabel'] = train_data['diagnosis'].apply(get_multilabel)

# %%
category =['0','1','2','3','4']
MLB = MultiLabelBinarizer(category)
y_train_org_multi = MLB.fit_transform(train_data['multilabel']).astype('float32')

# %% [markdown]
# ### Define class weights

# %%
class_weight = dict(zip(range(0, num_classes), (((train_data['diagnosis'].value_counts()).sort_index())/len(train_data)).tolist()))

# %% [markdown]
# ### Convert and scale image data

# %%
mean = X_train_org.mean(axis=0)
X_train_org = X_train_org.astype('float32')
X_train_org -= X_train_org.mean(axis=0)
std = X_train_org.std(axis=0)
X_train_org /= X_train_org.std(axis=0)
X_test = X_test.astype('float32')
X_test -= mean
X_test /= std

# %% [markdown]
# ### Split train and validation data

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train_org, y_train_org_multi,
                                                  test_size=0.1, random_state=0)

# %% [markdown]
# ### Create the model

# %%
from keras.applications import ResNet50

# %%
conv_base = ResNet50(weights='/kaggle/input/models/model_weights_resnet.h5',
                  include_top=False,
                  input_shape=(q_size, q_size, img_channel))
conv_base.trainable = True

# %%
model = Sequential()
model.add(conv_base)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5, activation='sigmoid'))

# %%
model.compile(optimizer = Adam(lr=5e-7),
              loss='binary_crossentropy',
              metrics=['binary_accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 5, 5, 2048)        23587712
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               26214912
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 49,805,189
# Trainable params: 49,752,069
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
epochs = 50
batch_size = 32

# %% [markdown]
# ### Train the model

# %%
history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(X_val, y_val),
                    class_weight=class_weight)
# Out:
# Train on 6660 samples, validate on 740 samples
# Epoch 1/50
# 6660/6660 [==============================] - 49s 7ms/step - loss: 0.1524 - binary_accuracy: 0.6970 - val_loss: 0.4177 - val_binary_accuracy: 0.8168
# Epoch 2/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.1067 - binary_accuracy: 0.7788 - val_loss: 0.3348 - val_binary_accuracy: 0.8632
# Epoch 3/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0875 - binary_accuracy: 0.8166 - val_loss: 0.2937 - val_binary_accuracy: 0.8789
# Epoch 4/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0774 - binary_accuracy: 0.8396 - val_loss: 0.2634 - val_binary_accuracy: 0.8903
# Epoch 5/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0692 - binary_accuracy: 0.8570 - val_loss: 0.2424 - val_binary_accuracy: 0.8989
# Epoch 6/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0640 - binary_accuracy: 0.8662 - val_loss: 0.2258 - val_binary_accuracy: 0.9092
# Epoch 7/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0578 - binary_accuracy: 0.8779 - val_loss: 0.2125 - val_binary_accuracy: 0.9146
# Epoch 8/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0542 - binary_accuracy: 0.8857 - val_loss: 0.2022 - val_binary_accuracy: 0.9184
# Epoch 9/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0509 - binary_accuracy: 0.8944 - val_loss: 0.1918 - val_binary_accuracy: 0.9241
# Epoch 10/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0479 - binary_accuracy: 0.8988 - val_loss: 0.1828 - val_binary_accuracy: 0.9265
# Epoch 11/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0453 - binary_accuracy: 0.9053 - val_loss: 0.1755 - val_binary_accuracy: 0.9316
# Epoch 12/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0424 - binary_accuracy: 0.9113 - val_loss: 0.1686 - val_binary_accuracy: 0.9338
# Epoch 13/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0404 - binary_accuracy: 0.9157 - val_loss: 0.1628 - val_binary_accuracy: 0.9368
# Epoch 14/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0391 - binary_accuracy: 0.9203 - val_loss: 0.1576 - val_binary_accuracy: 0.9384
# Epoch 15/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0372 - binary_accuracy: 0.9208 - val_loss: 0.1524 - val_binary_accuracy: 0.9411
# Epoch 16/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0354 - binary_accuracy: 0.9261 - val_loss: 0.1475 - val_binary_accuracy: 0.9422
# Epoch 17/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0335 - binary_accuracy: 0.9314 - val_loss: 0.1424 - val_binary_accuracy: 0.9462
# Epoch 18/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0313 - binary_accuracy: 0.9357 - val_loss: 0.1384 - val_binary_accuracy: 0.9484
# Epoch 19/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0303 - binary_accuracy: 0.9372 - val_loss: 0.1351 - val_binary_accuracy: 0.9492
# Epoch 20/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0292 - binary_accuracy: 0.9408 - val_loss: 0.1310 - val_binary_accuracy: 0.9514
# Epoch 21/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0277 - binary_accuracy: 0.9428 - val_loss: 0.1277 - val_binary_accuracy: 0.9532
# Epoch 22/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0265 - binary_accuracy: 0.9474 - val_loss: 0.1238 - val_binary_accuracy: 0.9530
# Epoch 23/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0253 - binary_accuracy: 0.9504 - val_loss: 0.1203 - val_binary_accuracy: 0.9559
# Epoch 24/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0245 - binary_accuracy: 0.9518 - val_loss: 0.1172 - val_binary_accuracy: 0.9576
# Epoch 25/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0229 - binary_accuracy: 0.9555 - val_loss: 0.1154 - val_binary_accuracy: 0.9581
# Epoch 26/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0225 - binary_accuracy: 0.9560 - val_loss: 0.1127 - val_binary_accuracy: 0.9592
# Epoch 27/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0211 - binary_accuracy: 0.9603 - val_loss: 0.1103 - val_binary_accuracy: 0.9589
# Epoch 28/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0209 - binary_accuracy: 0.9607 - val_loss: 0.1077 - val_binary_accuracy: 0.9608
# Epoch 29/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0194 - binary_accuracy: 0.9632 - val_loss: 0.1053 - val_binary_accuracy: 0.9614
# Epoch 30/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0186 - binary_accuracy: 0.9665 - val_loss: 0.1031 - val_binary_accuracy: 0.9619
# Epoch 31/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0183 - binary_accuracy: 0.9671 - val_loss: 0.1015 - val_binary_accuracy: 0.9627
# Epoch 32/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0171 - binary_accuracy: 0.9691 - val_loss: 0.1000 - val_binary_accuracy: 0.9630
# Epoch 33/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0164 - binary_accuracy: 0.9704 - val_loss: 0.0990 - val_binary_accuracy: 0.9638
# Epoch 34/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0160 - binary_accuracy: 0.9714 - val_loss: 0.0971 - val_binary_accuracy: 0.9651
# Epoch 35/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0151 - binary_accuracy: 0.9733 - val_loss: 0.0959 - val_binary_accuracy: 0.9654
# Epoch 36/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0145 - binary_accuracy: 0.9739 - val_loss: 0.0943 - val_binary_accuracy: 0.9657
# Epoch 37/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0141 - binary_accuracy: 0.9749 - val_loss: 0.0931 - val_binary_accuracy: 0.9673
# Epoch 38/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0133 - binary_accuracy: 0.9771 - val_loss: 0.0924 - val_binary_accuracy: 0.9676
# Epoch 39/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0129 - binary_accuracy: 0.9780 - val_loss: 0.0908 - val_binary_accuracy: 0.9676
# Epoch 40/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0121 - binary_accuracy: 0.9797 - val_loss: 0.0897 - val_binary_accuracy: 0.9686
# Epoch 41/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0120 - binary_accuracy: 0.9798 - val_loss: 0.0891 - val_binary_accuracy: 0.9686
# Epoch 42/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0115 - binary_accuracy: 0.9806 - val_loss: 0.0882 - val_binary_accuracy: 0.9686
# Epoch 43/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0111 - binary_accuracy: 0.9820 - val_loss: 0.0882 - val_binary_accuracy: 0.9686
# Epoch 44/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0106 - binary_accuracy: 0.9827 - val_loss: 0.0874 - val_binary_accuracy: 0.9697
# Epoch 45/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0106 - binary_accuracy: 0.9820 - val_loss: 0.0854 - val_binary_accuracy: 0.9692
# Epoch 47/50
# 6660/6660 [==============================] - 30s 5ms/step - loss: 0.0095 - binary_accuracy: 0.9850 - val_loss: 0.0857 - val_binary_accuracy: 0.9692
# Epoch 48/50
# 6660/6660 [==============================] - 31s 5ms/step - loss: 0.0091 - binary_accuracy: 0.9858 - val_loss: 0.0854 - val_binary_accuracy: 0.9695
# Epoch 49/50
# 6660/6660 [==============================] - 31s 5ms/step - loss: 0.0087 - binary_accuracy: 0.9860 - val_loss: 0.0852 - val_binary_accuracy: 0.9695
# Epoch 50/50
# 6660/6660 [==============================] - 31s 5ms/step - loss: 0.0087 - binary_accuracy: 0.9860 - val_loss: 0.0851 - val_binary_accuracy: 0.9695

# %% [markdown]
# ### Predict on the test images

# %%
y_test = model.predict(X_test)

# %%
y_op = model.predict(X_val)
y_op_classes = np.where(y_op>0.5, 1, 0).sum(axis=1)-1
y_val_classes = np.where(y_val>0.5, 1, 0).sum(axis=1)-1

# %%
y_test_classes = np.where(y_test>0.5, 1, 0).sum(axis=1)-1

# %% [markdown]
# ### Write output for submission

# %%
output = pd.DataFrame({'id_code': sub_org['id_code'],
                       'diagnosis': y_test_classes})
output.to_csv('submission.csv', index=False)

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_val_classes, y_op_classes)
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
plot_bar(output['diagnosis'])

# %% [markdown]
# ### Visualize the results

# %%
loss = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss, 'bo', label='loss_train')
plt.plot(epochs, loss_val, 'b', label='los_val')
plt.title('Value of the loss-function')
plt.xlabel('Epochs')
plt.ylabel('Value of the loss-function')
plt.legend()
plt.grid()
plt.show()

# %%
acc = history.history['binary_accuracy']
acc_val = history.history['val_binary_accuracy']
epochs = range(1, len(loss)+1)
plt.plot(epochs, acc, 'bo', label='Accuracy_Train')
plt.plot(epochs, acc_val, 'b', label='Accuracy_Val')
plt.title('Value of the accurarcy')
plt.xlabel('Epochs')
plt.ylabel('Value of the accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
from keras.applications import DenseNet169

# %%
densenet169 = DenseNet169(weights='/kaggle/input/tf-keras-pretrained-model-weights/No Top/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5',
                  include_top=False,
                  input_shape=(q_size, q_size, img_channel))
densenet169.trainable = True

# %%
from keras import layers
model1 = Sequential()
model1.add(densenet169)
model1.add(layers.GlobalAveragePooling2D())
model1.add(Dropout(0.5))
model1.add(Dense(5, activation='sigmoid'))

# %%
model1.compile(optimizer = Adam(lr=5e-7),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet169 (Model)          (None, 4, 4, 1664)        12642880
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1664)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1664)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 8325
# =================================================================
# Total params: 12,651,205
# Trainable params: 12,492,805
# Non-trainable params: 158,400
# _________________________________________________________________

# %%
epochs=50
batch=32

# %%
history1 = model1.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(X_val, y_val),
                    class_weight=class_weight)
# Out:
# Train on 6660 samples, validate on 740 samples
# Epoch 1/50
# 6660/6660 [==============================] - 95s 14ms/step - loss: 0.1910 - acc: 0.4717 - val_loss: 0.8203 - val_acc: 0.4816
# Epoch 2/50
# 6660/6660 [==============================] - 44s 7ms/step - loss: 0.1773 - acc: 0.5124 - val_loss: 0.7544 - val_acc: 0.5292
# Epoch 3/50
# 6660/6660 [==============================] - 44s 7ms/step - loss: 0.1653 - acc: 0.5467 - val_loss: 0.7067 - val_acc: 0.5665
# Epoch 4/50
# 6660/6660 [==============================] - 44s 7ms/step - loss: 0.1549 - acc: 0.5751 - val_loss: 0.6634 - val_acc: 0.6105
# Epoch 5/50
# 6660/6660 [==============================] - 44s 7ms/step - loss: 0.1459 - acc: 0.6048 - val_loss: 0.6271 - val_acc: 0.6341
# Epoch 6/50
# 6660/6660 [==============================] - 44s 7ms/step - loss: 0.1370 - acc: 0.6308 - val_loss: 0.5935 - val_acc: 0.6600
# Epoch 7/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.1312 - acc: 0.6542 - val_loss: 0.5618 - val_acc: 0.6841
# Epoch 8/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.1235 - acc: 0.6715 - val_loss: 0.5291 - val_acc: 0.7178
# Epoch 9/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.1168 - acc: 0.6950 - val_loss: 0.5073 - val_acc: 0.7349
# Epoch 10/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.1116 - acc: 0.7104 - val_loss: 0.4819 - val_acc: 0.7549
# Epoch 11/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.1067 - acc: 0.7264 - val_loss: 0.4578 - val_acc: 0.7795
# Epoch 12/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.1023 - acc: 0.7416 - val_loss: 0.4355 - val_acc: 0.8000
# Epoch 13/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0983 - acc: 0.7522 - val_loss: 0.4163 - val_acc: 0.8178
# Epoch 14/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0943 - acc: 0.7714 - val_loss: 0.3989 - val_acc: 0.8330
# Epoch 15/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0898 - acc: 0.7844 - val_loss: 0.3817 - val_acc: 0.8468
# Epoch 16/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0871 - acc: 0.7952 - val_loss: 0.3669 - val_acc: 0.8614
# Epoch 17/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0834 - acc: 0.8047 - val_loss: 0.3518 - val_acc: 0.8738
# Epoch 18/50
# 6660/6660 [==============================] - 44s 7ms/step - loss: 0.0800 - acc: 0.8192 - val_loss: 0.3380 - val_acc: 0.8843
# Epoch 19/50
# 6660/6660 [==============================] - 43s 7ms/step - loss: 0.0776 - acc: 0.8261 - val_loss: 0.3252 - val_acc: 0.8914
# Epoch 20/50
# 6660/6660 [==============================] - 43s 7ms/step - loss: 0.0752 - acc: 0.8342 - val_loss: 0.3150 - val_acc: 0.8962
# Epoch 21/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0725 - acc: 0.8463 - val_loss: 0.3036 - val_acc: 0.9046
# Epoch 22/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0706 - acc: 0.8501 - val_loss: 0.2930 - val_acc: 0.9100
# Epoch 23/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0688 - acc: 0.8585 - val_loss: 0.2843 - val_acc: 0.9124
# Epoch 24/50
# 6660/6660 [==============================] - 44s 7ms/step - loss: 0.0656 - acc: 0.8673 - val_loss: 0.2762 - val_acc: 0.9143
# Epoch 25/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0643 - acc: 0.8710 - val_loss: 0.2673 - val_acc: 0.9168
# Epoch 26/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0623 - acc: 0.8777 - val_loss: 0.2593 - val_acc: 0.9195
# Epoch 27/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0609 - acc: 0.8788 - val_loss: 0.2528 - val_acc: 0.9211
# Epoch 28/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0592 - acc: 0.8858 - val_loss: 0.2459 - val_acc: 0.9211
# Epoch 29/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0582 - acc: 0.8884 - val_loss: 0.2393 - val_acc: 0.9222
# Epoch 30/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0564 - acc: 0.8927 - val_loss: 0.2334 - val_acc: 0.9254
# Epoch 31/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0550 - acc: 0.8959 - val_loss: 0.2289 - val_acc: 0.9270
# Epoch 32/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0534 - acc: 0.9009 - val_loss: 0.2235 - val_acc: 0.9295
# Epoch 33/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0524 - acc: 0.9013 - val_loss: 0.2181 - val_acc: 0.9316
# Epoch 34/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0513 - acc: 0.9052 - val_loss: 0.2128 - val_acc: 0.9343
# Epoch 35/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0502 - acc: 0.9073 - val_loss: 0.2089 - val_acc: 0.9351
# Epoch 36/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0486 - acc: 0.9148 - val_loss: 0.2045 - val_acc: 0.9373
# Epoch 37/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0483 - acc: 0.9125 - val_loss: 0.1990 - val_acc: 0.9378
# Epoch 38/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0478 - acc: 0.9136 - val_loss: 0.1960 - val_acc: 0.9386
# Epoch 39/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0459 - acc: 0.9167 - val_loss: 0.1926 - val_acc: 0.9405
# Epoch 40/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0443 - acc: 0.9218 - val_loss: 0.1880 - val_acc: 0.9416
# Epoch 41/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0438 - acc: 0.9214 - val_loss: 0.1841 - val_acc: 0.9419
# Epoch 42/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0434 - acc: 0.9215 - val_loss: 0.1814 - val_acc: 0.9435
# Epoch 43/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0419 - acc: 0.9261 - val_loss: 0.1779 - val_acc: 0.9443
# Epoch 44/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0418 - acc: 0.9269 - val_loss: 0.1749 - val_acc: 0.9443
# Epoch 45/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0403 - acc: 0.9286 - val_loss: 0.1722 - val_acc: 0.9451
# Epoch 46/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0395 - acc: 0.9297 - val_loss: 0.1692 - val_acc: 0.9459
# Epoch 47/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0394 - acc: 0.9317 - val_loss: 0.1670 - val_acc: 0.9476
# Epoch 48/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0386 - acc: 0.9313 - val_loss: 0.1634 - val_acc: 0.9495
# Epoch 49/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0372 - acc: 0.9341 - val_loss: 0.1609 - val_acc: 0.9500
# Epoch 50/50
# 6660/6660 [==============================] - 43s 6ms/step - loss: 0.0371 - acc: 0.9351 - val_loss: 0.1583 - val_acc: 0.9497

# %%
y_test1 = model1.predict(X_test)

# %%
y_op1 = model1.predict(X_val)
y_op_classes1 = np.where(y_op1>0.5, 1, 0).sum(axis=1)-1
y_val_classes1 = np.where(y_val>0.5, 1, 0).sum(axis=1)-1

# %%
y_test_classes1 = np.where(y_test1>0.5, 1, 0).sum(axis=1)-1

# %%
output1 = pd.DataFrame({'id_code': sub_org['id_code'],
                       'diagnosis': y_test_classes1})
output1.to_csv('submission.csv', index=False)

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_val_classes1, y_op_classes1)
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
plot_bar(output1['diagnosis'])

# %%
loss = history1.history['loss']
loss_val = history1.history['val_loss']
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss, 'bo', label='loss_train')
plt.plot(epochs, loss_val, 'b', label='los_val')
plt.title('Value of the loss-function')
plt.xlabel('Epochs')
plt.ylabel('Value of the loss-function')
plt.legend()
plt.grid()
plt.show()

# %%
acc = history1.history['acc']
acc_val = history1.history['val_acc']
epochs = range(1, len(loss)+1)
plt.plot(epochs, acc, 'bo', label='Accuracy_Train')
plt.plot(epochs, acc_val, 'b', label='Accuracy_Val')
plt.title('Value of the accurarcy')
plt.xlabel('Epochs')
plt.ylabel('Value of the accuracy')
plt.legend()
plt.grid()
plt.show()
